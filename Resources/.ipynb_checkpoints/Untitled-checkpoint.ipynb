# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
intake_df = pd.read_csv("aac_intakes.csv", delimiter=',')
outcomes_df=pd.read_csv("aac_outcomes.csv", delimiter=',')

# %%
shelter_df=pd.merge(intake_df, outcomes_df, on="animal_id")

# %%
shelter_df.head()
# Out:
#   age_upon_intake animal_id animal_type_x  \
# 0         8 years   A706918           Dog
# 1       11 months   A724273           Dog
# 2         4 weeks   A665644           Cat
# 3         4 years   A682524           Dog
# 4         2 years   A743852           Dog
#
#                                  breed_x      color_x  \
# 0               English Springer Spaniel  White/Liver
# 1                            Basenji Mix  Sable/White
# 2                 Domestic Shorthair Mix       Calico
# 3  Doberman Pinsch/Australian Cattle Dog     Tan/Gray
# 4                 Labrador Retriever Mix    Chocolate
#
#                 datetime_x                datetime2  \
# 0  2015-07-05T12:59:00.000  2015-07-05T12:59:00.000
# 1  2016-04-14T18:43:00.000  2016-04-14T18:43:00.000
# 2  2013-10-21T07:59:00.000  2013-10-21T07:59:00.000
# 3  2014-06-29T10:38:00.000  2014-06-29T10:38:00.000
# 4  2017-02-18T12:46:00.000  2017-02-18T12:46:00.000
#
# ...

# %%
shelter_df.columns.values
# Out:
# array(['age_upon_intake', 'animal_id', 'animal_type_x', 'breed_x',
#        'color_x', 'datetime_x', 'datetime2', 'found_location',
#        'intake_condition', 'intake_type', 'name_x', 'sex_upon_intake',
#        'age_upon_outcome', 'animal_type_y', 'breed_y', 'color_y',
#        'date_of_birth', 'datetime_y', 'monthyear', 'name_y',
#        'outcome_subtype', 'outcome_type', 'sex_upon_outcome'],
#       dtype=object)

# %%
dog= shelter_df.loc[shelter_df["animal_type_x"]=="Dog"]
dog.head()
# Out:
#   age_upon_intake animal_id animal_type_x  \
# 0         8 years   A706918           Dog
# 1       11 months   A724273           Dog
# 3         4 years   A682524           Dog
# 4         2 years   A743852           Dog
# 5         2 years   A708452           Dog
#
#                                  breed_x      color_x  \
# 0               English Springer Spaniel  White/Liver
# 1                            Basenji Mix  Sable/White
# 3  Doberman Pinsch/Australian Cattle Dog     Tan/Gray
# 4                 Labrador Retriever Mix    Chocolate
# 5                 Labrador Retriever Mix  Black/White
#
#                 datetime_x                datetime2  \
# 0  2015-07-05T12:59:00.000  2015-07-05T12:59:00.000
# 1  2016-04-14T18:43:00.000  2016-04-14T18:43:00.000
# 3  2014-06-29T10:38:00.000  2014-06-29T10:38:00.000
# 4  2017-02-18T12:46:00.000  2017-02-18T12:46:00.000
# 5  2015-07-30T14:37:00.000  2015-07-30T14:37:00.000
#
# ...

# %%
test=dog

# %%
test['datetime_x'] =pd.to_datetime( test['datetime_x']).dt.strftime('%m/%d/%Y')
test.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1860         try:
# -> 1861             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1862             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-af9962f32004> in <module>
# ----> 1 test['datetime_x'] =pd.to_datetime( test['datetime_x']).dt.strftime('%m/%d/%Y')
#       2 test.head()
#
# ...

# %%
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test.head()
# Out:
#   age_upon_intake animal_id animal_type_x  \
# 0         8 years   A706918           Dog
# 1       11 months   A724273           Dog
# 3         4 years   A682524           Dog
# 4         2 years   A743852           Dog
# 5         2 years   A708452           Dog
#
#                                  breed_x      color_x  \
# 0               English Springer Spaniel  White/Liver
# 1                            Basenji Mix  Sable/White
# 3  Doberman Pinsch/Australian Cattle Dog     Tan/Gray
# 4                 Labrador Retriever Mix    Chocolate
# 5                 Labrador Retriever Mix  Black/White
#
#                 datetime_x                datetime2  \
# 0  2015-07-05T12:59:00.000  2015-07-05T12:59:00.000
# 1  2016-04-14T18:43:00.000  2016-04-14T18:43:00.000
# 3  2014-06-29T10:38:00.000  2014-06-29T10:38:00.000
# 4  2017-02-18T12:46:00.000  2017-02-18T12:46:00.000
# 5  2015-07-30T14:37:00.000  2015-07-30T14:37:00.000
#
# ...

# %%
import datetime
d1 = datetime.datetime.strptime("2013-07-12T07:00:00Z","%Y-%m-%dT%H:%M:%SZ")
