# %% [markdown]
# # Austin Animal Shelter
#
# Analysis of dogs at AAS. What types of breeds are coming into the shelter and how long do they stay. What breeds are getting adopted and where animals are found around the city of Austin. The data will be coming from a Kaggle dataset found here:
# https://www.kaggle.com/aaronschlegel/austin-animal-center-shelter-intakes-and-outcomes
#
# Austin Animal Center Austin, Texas is the largest No Kill community in the nation, and home to the Austin Animal Center. We provide shelter to more than 16,000 animals each year and animal protection and pet resource services to all of Austin and Travis County.
#
# The Austin Animal Center is an open-intake facility where lost and surrendered animals from all of Travis County in need of shelter are accepted regardless of age, health, species or breed. The goal of the Austin Animal Center is to place all adoptable animals in forever homes.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functions import sep_breeds
from functions import clean
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %%
ifile1 = '../Resources/aac_intakes_outcomes.csv'
ifile2 = '../Resources/aac_outcomes.csv'
ifile3 = '../Resources/aac_intakes.csv'

io_df = pd.read_csv(ifile1)
o_df = pd.read_csv(ifile2)
i_df = pd.read_csv(ifile3)

# %% [markdown]
# ## Selecting top 20 dog breeds

# %%
columns = [
    'breed',
    'animal_id',
    'found_location'
]

dogs = i_df.loc[i_df['animal_type'] == 'Dog', columns]

# %%
dogs['breed'] = dogs['breed'].apply(sep_breeds)

# %%
breeds_20 = dogs['breed'].value_counts()
top20 = breeds_20.index[:20]

dogs_20 = pd.DataFrame({
    'breed':[],
    'animal_id':[]
})
for i in top20:
    df3 = dogs.loc[dogs['breed'] == i]
    #print(df3.head())
    dogs_20 = dogs_20.append(df3)
# Out:
# C:\Apps\Anaconda\envs\pythondata\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
io_df = io_df.rename(columns ={
    'animal_id_outcome':'animal_id'
})

iio_df = dogs_20.merge(io_df, on='animal_id',how='inner')

iio_df['new_outcome_type'] = iio_df['outcome_type'].apply(clean)
iio_df=iio_df.dropna(subset=['new_outcome_type'])

# %%
age_bins = [0, 1.5, 6, 25]
group_names = ["Puppy (<1.5)", "Adult (1.5 - 6)", "Senior (>6)"]
iio_df['age_group'] = pd.cut(iio_df['age_upon_outcome_(years)'],
                          age_bins,labels = group_names)

breed_group = iio_df.groupby('breed_x')
age_group = iio_df.groupby('age_group')
outcome_age_group = iio_df.groupby(['new_outcome_type','age_group'])
outcome_breed_group = iio_df.groupby(['new_outcome_type','breed_x'])
outcome_group = iio_df.groupby('new_outcome_type')
# Out:
#     animal_id       breed_x                       found_location_x  \
# 0     A700396  Pit Bull Mix    4200 Smith School Rd in Austin (TX)
# 1     A700396  Pit Bull Mix    4200 Smith School Rd in Austin (TX)
# 2     A700396  Pit Bull Mix    4200 Smith School Rd in Austin (TX)
# 3     A700396  Pit Bull Mix    4200 Smith School Rd in Austin (TX)
# 4     A700396  Pit Bull Mix    4200 Smith School Rd in Austin (TX)
# 37    A740584  Pit Bull Mix        20412 Keilman Ln in Travis (TX)
# 38    A687473  Pit Bull Mix            16403 Summit in Travis (TX)
# 74    A714106  Pit Bull Mix                 183/Mlk in Travis (TX)
# 76    A714106  Pit Bull Mix            4700 Sara Dr in Austin (TX)
# 78    A695799  Pit Bull Mix                            Austin (TX)
# 96    A674489  Pit Bull Mix                            Austin (TX)
# 98    A674489  Pit Bull Mix  1402 Cool Shadow Dr in Del Valle (TX)
# 100   A735718  Pit Bull Mix      6207 Dorchester Dr in Austin (TX)
# 118   A696283  Pit Bull Mix                            Austin (TX)
# 120   A696283  Pit Bull Mix             A/C Seizure in Austin (TX)
#
#     age_upon_outcome        date_of_birth      outcome_subtype  \
# 0            4 years  2012-04-13 00:00:00                  NaN
# 1            3 years  2012-04-13 00:00:00                  NaN
# 2            3 years  2012-04-13 00:00:00                  NaN
# 3            3 years  2012-04-13 00:00:00                  NaN
# 4            3 years  2012-04-13 00:00:00                  NaN
# 37          6 months  2016-06-19 00:00:00              Partner
# 38           1 month  2014-07-29 00:00:00              Partner
# 74            1 year  2014-10-18 00:00:00              Partner
# 76            1 year  2014-10-18 00:00:00              Partner
# 78           3 years  2012-01-23 00:00:00           Aggressive
# 96           2 years  2011-09-13 00:00:00           Aggressive
# 98           2 years  2011-09-13 00:00:00           Aggressive
# 100          3 years  2013-09-27 00:00:00              Partner
# 118          3 years  2013-02-02 00:00:00  Court/Investigation
# 120          3 years  2013-02-02 00:00:00  Court/Investigation
#
#         outcome_type sex_upon_outcome  age_upon_outcome_(days)  \
# 0           Adoption    Spayed Female                     1460
# 1    Return to Owner    Spayed Female                     1095
# 2    Return to Owner    Spayed Female                     1095
# 3    Return to Owner    Spayed Female                     1095
# 4    Return to Owner    Spayed Female                     1095
# 37          Transfer    Intact Female                      180
# 38          Transfer      Intact Male                       30
# 74          Transfer    Neutered Male                      365
# 76          Transfer    Neutered Male                      365
# 78        Euthanasia    Neutered Male                     1095
# 96        Euthanasia    Spayed Female                      730
# 98        Euthanasia    Spayed Female                      730
# 100         Transfer    Neutered Male                     1095
# 118       Euthanasia    Spayed Female                     1095
# 120       Euthanasia    Spayed Female                     1095
#
#      age_upon_outcome_(years)  ... intake_month intake_year  intake_monthyear  \
# 0                    4.000000  ...            9        2016           2016-09
# 1                    3.000000  ...           12        2015           2015-12
# 2                    3.000000  ...           12        2015           2015-12
# 3                    3.000000  ...           11        2015           2015-11
# 4                    3.000000  ...            9        2015           2015-09
# 37                   0.493151  ...           12        2016           2016-12
# 38                   0.082192  ...            9        2014           2014-09
# 74                   1.000000  ...           11        2015           2015-11
# 76                   1.000000  ...           11        2015           2015-11
# 78                   3.000000  ...            1        2015           2015-01
# 96                   2.000000  ...            6        2014           2014-06
# 98                   2.000000  ...            6        2014           2014-06
# 100                  3.000000  ...            9        2016           2016-09
# 118                  3.000000  ...            2        2016           2016-02
# 120                  3.000000  ...            2        2016           2016-02
#
#      intake_weekday intake_hour intake_number             time_in_shelter  \
# 0           Tuesday          18           1.0  74 days 19:03:00.000000000
# 1           Tuesday           8           2.0   5 days 09:25:00.000000000
# 2            Monday           9           3.0   1 days 02:34:00.000000000
# 3           Tuesday          10           4.0   2 days 06:57:00.000000000
# 4            Monday          10           5.0   2 days 07:34:00.000000000
# 37           Monday          17           1.0   3 days 19:32:00.000000000
# 38           Friday          10           1.0   1 days 04:07:00.000000000
# 74           Friday          12           1.0  20 days 11:04:00.000000000
# 76           Friday          12           1.0  20 days 11:04:00.000000000
# 78           Friday          12           1.0   0 days 20:33:00.000000000
# 96        Wednesday          18           1.0   0 days 19:17:00.000000000
# 98        Wednesday          18           1.0   0 days 19:17:00.000000000
# 100         Tuesday          19           1.0  91 days 18:58:00.000000000
# 118         Tuesday          13           1.0  30 days 00:28:00.000000000
# 120         Tuesday          13           1.0  30 days 00:28:00.000000000
#
#      time_in_shelter_days  new_outcome_type        age_group
# 0               74.793750  Positive Outcome  Adult (1.5 - 6)
# 1                5.392361  Positive Outcome  Adult (1.5 - 6)
# 2                1.106944  Positive Outcome  Adult (1.5 - 6)
# 3                2.289583  Positive Outcome  Adult (1.5 - 6)
# 4                2.315278  Positive Outcome  Adult (1.5 - 6)
# 37               3.813889          Transfer     Puppy (<1.5)
# 38               1.171528          Transfer     Puppy (<1.5)
# 74              20.461111          Transfer     Puppy (<1.5)
# 76              20.461111          Transfer     Puppy (<1.5)
# 78               0.856250  Negative Outcome  Adult (1.5 - 6)
# 96               0.803472  Negative Outcome  Adult (1.5 - 6)
# 98               0.803472  Negative Outcome  Adult (1.5 - 6)
# 100             91.790278          Transfer  Adult (1.5 - 6)
# 118             30.019444  Negative Outcome  Adult (1.5 - 6)
# 120             30.019444  Negative Outcome  Adult (1.5 - 6)
#
# [15 rows x 45 columns]

# %%
mean_breed_time = breed_group.agg({
    'time_in_shelter_days':['mean']
})
mean_breed_time.columns = mean_breed_time.columns.droplevel()
mean_breed_time1 = mean_breed_time.sort_values('mean')

mean_age_time = age_group.agg({
    'time_in_shelter_days':['mean']
})

age_outcome = outcome_age_group.agg({
    'age_group':['count']
})

breed_outcome = outcome_breed_group.agg({
    'breed_x':['count']
})

# %% [markdown]
# ## Time in Shelter (days)

# %%
intakes_outcomes = pd.read_csv("../Resources/aac_intakes_outcomes.csv")

# %%
# intakes_outcomes data cleanup
intakes_outcomes_cleaned = intakes_outcomes.drop(['sex_upon_outcome', 'intake_weekday','intake_hour','intake_number','time_in_shelter','intake_monthyear','intake_datetime'], axis=1)
intakes_outcomes_cleaned.drop_duplicates(subset='animal_id_outcome', keep='first', inplace=True)
intakes_outcomes_cleaned= intakes_outcomes_cleaned.loc[intakes_outcomes_cleaned["animal_type"]=="Dog"]
intakes_outcomes_cleaned.head()
# Out:
#   age_upon_outcome animal_id_outcome        date_of_birth outcome_subtype  \
# 0         10 years           A006100  2007-07-09 00:00:00             NaN
# 3         10 years           A047759  2004-04-02 00:00:00         Partner
# 4         16 years           A134067  1997-10-16 00:00:00             NaN
# 5         15 years           A141142  1998-06-01 00:00:00             NaN
# 6         15 years           A163459  1999-10-19 00:00:00             NaN
#
#       outcome_type  age_upon_outcome_(days)  age_upon_outcome_(years)  \
# 0  Return to Owner                     3650                      10.0
# 3         Transfer                     3650                      10.0
# 4  Return to Owner                     5840                      16.0
# 5  Return to Owner                     5475                      15.0
# 6  Return to Owner                     5475                      15.0
#
#   age_upon_outcome_age_group     outcome_datetime  outcome_month  ...  \
# 0                (7.5, 10.0]  2017-12-07 14:07:00             12  ...
# 3                (7.5, 10.0]  2014-04-07 15:12:00              4  ...
# 4               (15.0, 17.5]  2013-11-16 11:54:00             11  ...
# 5               (12.5, 15.0]  2013-11-17 11:40:00             11  ...
# 6               (12.5, 15.0]  2014-11-14 19:28:00             11  ...
#
#    intake_condition      intake_type sex_upon_intake  count  \
# 0            Normal            Stray   Neutered Male      1
# 3            Normal  Owner Surrender   Neutered Male      1
# 4           Injured    Public Assist   Neutered Male      1
# 5              Aged            Stray   Spayed Female      1
# 6            Normal            Stray   Intact Female      1
#
#    age_upon_intake_(days)  age_upon_intake_(years)  age_upon_intake_age_group  \
# 0                    3650                     10.0                (7.5, 10.0]
# 3                    3650                     10.0                (7.5, 10.0]
# 4                    5840                     16.0               (15.0, 17.5]
# 5                    5475                     15.0               (12.5, 15.0]
# 6                    5475                     15.0               (12.5, 15.0]
#
#   intake_month intake_year time_in_shelter_days
# 0           12        2017             0.588194
# 3            4        2014             4.970139
# 4           11        2013             0.119444
# 5           11        2013             0.870833
# 6           11        2014             0.178472
#
# [5 rows x 34 columns]

# %%
# intakes_outcomes data cleanup
intakes_outcomes_cleaned = intakes_outcomes.drop(['sex_upon_outcome', 'intake_weekday','intake_hour','intake_number','time_in_shelter','intake_monthyear','intake_datetime'], axis=1)
intakes_outcomes_cleaned.drop_duplicates(subset='animal_id_outcome', keep='first', inplace=True)
intakes_outcomes_cleaned= intakes_outcomes_cleaned.loc[intakes_outcomes_cleaned["animal_type"]=="Dog"]
intakes_outcomes_cleaned.head()
# Out:
#   age_upon_outcome animal_id_outcome        date_of_birth outcome_subtype  \
# 0         10 years           A006100  2007-07-09 00:00:00             NaN
# 3         10 years           A047759  2004-04-02 00:00:00         Partner
# 4         16 years           A134067  1997-10-16 00:00:00             NaN
# 5         15 years           A141142  1998-06-01 00:00:00             NaN
# 6         15 years           A163459  1999-10-19 00:00:00             NaN
#
#       outcome_type  age_upon_outcome_(days)  age_upon_outcome_(years)  \
# 0  Return to Owner                     3650                      10.0
# 3         Transfer                     3650                      10.0
# 4  Return to Owner                     5840                      16.0
# 5  Return to Owner                     5475                      15.0
# 6  Return to Owner                     5475                      15.0
#
#   age_upon_outcome_age_group     outcome_datetime  outcome_month  ...  \
# 0                (7.5, 10.0]  2017-12-07 14:07:00             12  ...
# 3                (7.5, 10.0]  2014-04-07 15:12:00              4  ...
# 4               (15.0, 17.5]  2013-11-16 11:54:00             11  ...
# 5               (12.5, 15.0]  2013-11-17 11:40:00             11  ...
# 6               (12.5, 15.0]  2014-11-14 19:28:00             11  ...
#
#    intake_condition      intake_type sex_upon_intake  count  \
# 0            Normal            Stray   Neutered Male      1
# 3            Normal  Owner Surrender   Neutered Male      1
# 4           Injured    Public Assist   Neutered Male      1
# 5              Aged            Stray   Spayed Female      1
# 6            Normal            Stray   Intact Female      1
#
#    age_upon_intake_(days)  age_upon_intake_(years)  age_upon_intake_age_group  \
# 0                    3650                     10.0                (7.5, 10.0]
# 3                    3650                     10.0                (7.5, 10.0]
# 4                    5840                     16.0               (15.0, 17.5]
# 5                    5475                     15.0               (12.5, 15.0]
# 6                    5475                     15.0               (12.5, 15.0]
#
#   intake_month intake_year time_in_shelter_days
# 0           12        2017             0.588194
# 3            4        2014             4.970139
# 4           11        2013             0.119444
# 5           11        2013             0.870833
# 6           11        2014             0.178472
#
# [5 rows x 34 columns]

# %% [markdown]
# # Gmap - Intake Locations

# %%
import requests
import gmaps

from config import gkey
# conda install -c conda-forge rise
# pip install RISE
# jupyter-nbextension install rise --py --sys-prefix
# Configure gmaps
gmaps.configure(api_key=gkey)

# %% [markdown]
# ## Cleaning location data

# %%
intakes = pd.read_csv("../Resources/aac_intakes.csv")

# intakes data wrangling
intakes_cleaned = intakes.drop(['color', 'datetime', 'datetime2', 'name', 'sex_upon_intake'], axis=1)
intakes_cleaned.drop_duplicates(subset='animal_id', keep='first', inplace=True)
intakes_cleaned.dropna
new = intakes_cleaned['breed'].str.split('/',n=1, expand = True)

intakes_cleaned["breed_new"] = new[0]
intakes_cleaned["sub_breed_new"] = new[1]

for index, row in intakes_cleaned.iterrows():
    if row["sub_breed_new"] is not None:
        row["breed_new"] = row["breed_new"] +' Mix'

intakes_cleaned_dogs= intakes_cleaned.loc[intakes_cleaned["animal_type"]=="Dog"]
intakes_cleaned_dogs = intakes_cleaned_dogs.groupby('breed_new').filter(lambda group: len(group) > 430)
intakes_cleaned_dogs.head()
# Out:
#    age_upon_intake animal_id animal_type  \
# 4          2 years   A743852         Dog
# 5          2 years   A708452         Dog
# 14        2 months   A697950         Dog
# 18        4 months   A749436         Dog
# 21         1 month   A759935         Dog
#
#                                        breed  \
# 4                     Labrador Retriever Mix
# 5                     Labrador Retriever Mix
# 14  Australian Cattle Dog/Labrador Retriever
# 18                             Dachshund Mix
# 21                    Labrador Retriever Mix
#
#                                       found_location intake_condition  \
# 4                                        Austin (TX)           Normal
# 5                                        Austin (TX)           Normal
# 14                      1501 S Fm 973 in Austin (TX)           Normal
# 18  East Pleasant Valley And Stassney in Austin (TX)           Normal
# 21                 4800 Cottonwood St in Austin (TX)           Normal
#
#         intake_type                  breed_new       sub_breed_new
# 4   Owner Surrender     Labrador Retriever Mix                None
# 5     Public Assist     Labrador Retriever Mix                None
# 14            Stray  Australian Cattle Dog Mix  Labrador Retriever
# 18            Stray              Dachshund Mix                None
# 21            Stray     Labrador Retriever Mix                None

# %%
intakes_location = intakes_cleaned_dogs[intakes_cleaned_dogs["found_location"].str.len()>30]
addresses  = intakes_location["found_location"]
addresses.head()
# Out:
# 18    East Pleasant Valley And Stassney in Austin (TX)
# 21                   4800 Cottonwood St in Austin (TX)
# 22                  Guadalupe/St. Johns in Austin (TX)
# 28                 4200 Smith School Rd in Austin (TX)
# 33            11699 James B Connolly Ln in Austin (TX)
# Name: found_location, dtype: object

# %% [markdown]
# ## Geocode for lcoations

# %%
def get_google_results(address, api_key=None, return_full_response=False):
    
    
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    geocode_url = geocode_url + "&key={}".format(api_key)
        
    results = requests.get(geocode_url)
    results = results.json()
    
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "postcode": None
                }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
                }
        
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

# %%
import logging
import time

BACKOFF_TIME = 3000
RETURN_FULL_RESULTS = False
logger = logging.getLogger("root")
output_filename = ''
logger.setLevel(logging.DEBUG)
# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

counter = 0
results = []

for address in addresses:

    geocoded = False
    while geocoded is not True:
        

        try:
            geocode_result = get_google_results(address, gkey, return_full_response=RETURN_FULL_RESULTS)
        except Exception as e:
            logger.exception(e)
            logger.error("Skipping!")
            geocoded = True
            
#         if geocode_result['status'] != 'OK':
#             logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
        logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
        results.append(geocode_result)           
        geocoded = True
        counter = counter + 1 
        
    if len(results) == 1000:
        pd.DataFrame(results).to_csv("gmap_results.csv")
        break
logger.info("Finished geocoding all addresses")
# Out:
# name 'get_google_results' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-15-d887475a84fe>", line 24, in <module>
#     geocode_result = get_google_results(address, gkey, return_full_response=RETURN_FULL_RESULTS)
# NameError: name 'get_google_results' is not defined
# Skipping!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d887475a84fe> in <module>
#      30 #         if geocode_result['status'] != 'OK':
#      31 #             logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
# ---> 32         logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
#      33         results.append(geocode_result)
#      34         geocoded = True
#
# NameError: name 'geocode_result' is not defined

# %%
results_df = pd.read_csv("../Resources/gmap_results.csv")
results_df = pd.DataFrame(results_df)
# results_df

indexNames = results_df[ results_df['postcode'] == "" ].index
results_df.drop(indexNames , inplace=True)
# results_df.head()
locations = results_df[["latitude", "longitude","postcode"]]
# locations.head()
locations_grouped = locations.groupby("postcode").latitude.count()
locations_grouped = locations_grouped.reset_index()
# locations_grouped.head()

locations_grouped = locations_grouped.rename(columns={'latitude':'total_count'})
locations_grouped = locations_grouped.sort_values(by = ["total_count"], ascending = False)

# locations_grouped = locations_grouped.drop([0], axis=0)
# locations_grouped.head()
locations_merged = pd.merge(locations, locations_grouped, left_on='postcode', right_on='postcode', how ='inner')
locations_merged.head()
# Out:
#     latitude  longitude postcode  total_count
# 0  30.194003 -97.744737    78744           79
# 1  30.196593 -97.733247    78744           79
# 2  30.192835 -97.715279    78744           79
# 3  30.205669 -97.690594    78744           79
# 4  30.198444 -97.697174    78744           79

# %%
locations_coordinates = locations_merged[["latitude","longitude"]]
# locations_coordinates.head()
locations_weight = locations_merged["total_count"]
locations_weight.head()
# Out:
# 0    79
# 1    79
# 2    79
# 3    79
# 4    79
# Name: total_count, dtype: int64

# %%
# plt.figure(figsize=(12,12))
# sns.boxplot( x='outcome_type', y='age_upon_outcome_(years)', data= intakes_outcomes_cleaned)
# plt.title("Age by Outcome of Dogs")
# plt.xlabel("Outcomes")
# plt.ylabel("Age")
# plt.savefig("Age_by_Outcomes.png")
# plt.show()

# %%
intakes = pd.read_csv("../Resources/aac_intakes.csv")
outcomes = pd.read_csv("../Resources/aac_outcomes.csv")


# intakes data wrangling
intakes_cleaned = intakes.drop(['color', 'datetime', 'datetime2', 'name', 'sex_upon_intake'], axis=1)
intakes_cleaned.drop_duplicates(subset='animal_id', keep='first', inplace=True)
intakes_cleaned.dropna
new = intakes_cleaned['breed'].str.split('/',n=1, expand = True)

intakes_cleaned["breed_new"] = new[0]
intakes_cleaned["sub_breed_new"] = new[1]

for index, row in intakes_cleaned.iterrows():
    if row["sub_breed_new"] is not None:
        row["breed_new"] = row["breed_new"] +' Mix'

intakes_cleaned_dogs= intakes_cleaned.loc[intakes_cleaned["animal_type"]=="Dog"]
intakes_cleaned_dogs = intakes_cleaned_dogs.groupby('breed_new').filter(lambda group: len(group) > 430)
intakes_cleaned_dogs.head()
# Out:
#    age_upon_intake animal_id animal_type  \
# 4          2 years   A743852         Dog
# 5          2 years   A708452         Dog
# 14        2 months   A697950         Dog
# 18        4 months   A749436         Dog
# 21         1 month   A759935         Dog
#
#                                        breed  \
# 4                     Labrador Retriever Mix
# 5                     Labrador Retriever Mix
# 14  Australian Cattle Dog/Labrador Retriever
# 18                             Dachshund Mix
# 21                    Labrador Retriever Mix
#
#                                       found_location intake_condition  \
# 4                                        Austin (TX)           Normal
# 5                                        Austin (TX)           Normal
# 14                      1501 S Fm 973 in Austin (TX)           Normal
# 18  East Pleasant Valley And Stassney in Austin (TX)           Normal
# 21                 4800 Cottonwood St in Austin (TX)           Normal
#
#         intake_type                  breed_new       sub_breed_new
# 4   Owner Surrender     Labrador Retriever Mix                None
# 5     Public Assist     Labrador Retriever Mix                None
# 14            Stray  Australian Cattle Dog Mix  Labrador Retriever
# 18            Stray              Dachshund Mix                None
# 21            Stray     Labrador Retriever Mix                None

# %%
# Outcome data wrangling

outcome_cleaned = outcomes.drop(['color','date_of_birth','datetime','monthyear','sex_upon_outcome'], axis=1)
outcome_cleaned.drop_duplicates(subset='animal_id', keep='first', inplace=True)

outcome_cleaned['outcome_subtype'] = outcome_cleaned['outcome_subtype'].replace({'In Kennel': 'At Vet'})
outcome_cleaned['outcome_subtype'] = outcome_cleaned['outcome_subtype'].replace({'In Surgery': 'At Vet'})
outcome_cleaned['outcome_subtype'] = outcome_cleaned['outcome_subtype'].replace({'Aggressive': 'Behavior'})
outcome_cleaned['outcome_subtype'] = outcome_cleaned['outcome_subtype'].replace({'Court/Investigation': 'At Vet'})
outcome_cleaned['outcome_subtype'] = outcome_cleaned['outcome_subtype'].replace({'Rabies Risk': 'Medical'})

new_column = outcome_cleaned['breed'].str.split('/',n=1, expand = True)

outcome_cleaned["breed_new"] = new_column[0]
outcome_cleaned["sub_breed_new"] = new_column[1]

for index, row in outcome_cleaned.iterrows():
    if row["sub_breed_new"] is not None:
#         print(row["breed_new"])
        row["breed_new"] = row["breed_new"] +' Mix'
    
outcome_cleaned.head()
# Out:
#   age_upon_outcome animal_id animal_type                    breed     name  \
# 0          2 weeks   A684346         Cat   Domestic Shorthair Mix      NaN
# 1           1 year   A666430         Dog               Beagle Mix     Lucy
# 2           1 year   A675708         Dog                 Pit Bull  *Johnny
# 3          9 years   A680386         Dog  Miniature Schnauzer Mix   Monday
# 4         5 months   A683115       Other                  Bat Mix      NaN
#
#   outcome_subtype outcome_type                breed_new sub_breed_new
# 0         Partner     Transfer   Domestic Shorthair Mix          None
# 1         Partner     Transfer               Beagle Mix          None
# 2             NaN     Adoption                 Pit Bull          None
# 3         Partner     Transfer  Miniature Schnauzer Mix          None
# 4         Medical   Euthanasia                  Bat Mix          None

# %%
intakes_main_breeds_groupby = intakes_cleaned_dogs.groupby("breed_new").intake_type.count()

intakes_main_breeds_groupby = intakes_main_breeds_groupby.reset_index()
intakes_main_breeds_groupby = intakes_main_breeds_groupby.rename(columns={'intake_type':'total_count'})
intakes_main_breeds_groupby = intakes_main_breeds_groupby.sort_values(by = ["total_count"], ascending = False)
intakes_main_breeds_groupby.head()
# Out:
#                     breed_new  total_count
# 13               Pit Bull Mix         5368
# 10     Labrador Retriever Mix         5221
# 6     Chihuahua Shorthair Mix         5047
# 8         German Shepherd Mix         2013
# 0   Australian Cattle Dog Mix         1184

# %%
outcome_cleanded_dogs = outcome_cleaned.loc[outcome_cleaned["animal_type"]=="Dog"]
# outcome_cleanded_dogs.dropna
outcome_main_breeds = outcome_cleanded_dogs.groupby('breed_new').filter(lambda group: len(group) > 430)

outcome_main_breeds_groupby = outcome_main_breeds.loc[outcome_main_breeds["animal_type"]=="Dog"].groupby("breed_new").outcome_type.count()


outcome_main_breeds_groupby = outcome_main_breeds_groupby.reset_index()
outcome_main_breeds_groupby = outcome_main_breeds_groupby.rename(columns={'outcome_type':'total_count'})
outcome_main_breeds_groupby = outcome_main_breeds_groupby.sort_values(by = ["total_count"], ascending = False)
outcome_main_breeds_groupby.head()
# Out:
#                     breed_new  total_count
# 13               Pit Bull Mix         5369
# 10     Labrador Retriever Mix         5248
# 6     Chihuahua Shorthair Mix         5071
# 8         German Shepherd Mix         2023
# 0   Australian Cattle Dog Mix         1187

# %%
x_axis = intakes_main_breeds_groupby["breed_new"]
y_axis = intakes_main_breeds_groupby["total_count"]
plt.bar(x_axis, y_axis, color='r', alpha=0.5, align="center")
plt.title("Total Number of Dogs by Breed (Intakes)")
plt.xlabel("Breed")
plt.ylabel("Count")
plt.xticks(x_axis, rotation=-65,ha="left", rotation_mode="anchor")
plt.savefig("Total Number of Dogs by Breed (Intakes).png")

# %%
plt.show()

# %%
x_axis = outcome_main_breeds_groupby["breed_new"]
y_axis = outcome_main_breeds_groupby["total_count"]
plt.bar(x_axis, y_axis, color='b', alpha=0.5, align="center")
plt.title("Total Number of Dogs by Breed (Outcomes)")
plt.xlabel("Breed")
plt.ylabel("Count")
plt.xticks(x_axis, rotation=-65,ha="left", rotation_mode="anchor")
# plt.tight_layout()
plt.savefig("Total Number of Dogs by Breed (Outcomes).png")

# %%
mean_breed_time.plot.bar(legend=False, title='Time in Shelter by Breed',label = 'Time in Shelter(days)',rot=90)
x_axis = outcome_main_breeds_groupby["breed_new"]
plt.xlabel('Breed')
plt.ylabel('Mean Time in Shelter(days)')
plt.savefig('Mean Time in Shelter(days).png')

mean_age_time.plot.bar(legend=False, title='Time in Shelter by Age Group',label = 'Time in Shelter(days)',rot=-40)
plt.xlabel('Age Group')
plt.ylabel('Mean Time in Shelter(days)')
plt.savefig('Mean Time in Shelter(days).png')

age_outcome.plot.bar(legend=False, title='Outcome by Age Group',label = 'Time in Shelter(days)', figsize=(15,8))
plt.xlabel('Outcome/Age Group')
plt.ylabel('Time in Shelter(days)')
plt.savefig('Time in Shelter(days).png')


# breed_outcome.plot.bar(legend=False, title='Outcome by Breed',label = 'Time in Shelter(days)')
# plt.xlabel('Outcome/Breed')
# plt.ylabel('Time in Shelter(days)')
# plt.savefig('Time in Shelter(days).png')

fig, ax = plt.subplots(1,figsize=(15,10))

for name,group in outcome_group:
    ax.scatter(group['age_upon_outcome_(years)'],group['time_in_shelter_days'],label=name)
ax.legend()

fig.savefig('20scatter.png')
fig

# #Days a dog spent in shelter by age
# plt.figure(figsize=(15,10))
# sns.scatterplot(x='age_upon_intake_(years)', y='time_in_shelter_days' , data=intakes_outcomes_cleaned)
# plt.title('Days a dog spent in shelter by age')
# plt.show()


# # Time in Shelter (Days)
# sns.scatterplot(x='age_upon_intake_(years)', y='time_in_shelter_days' , data=intakes_outcomes_cleaned)

# Age upon Outcome (Years)
plt.figure(figsize=(12,12))
sns.boxplot( x='outcome_type', y='age_upon_outcome_(years)', data= intakes_outcomes_cleaned)
plt.title("Age by Outcome of Dogs")
plt.xlabel("Outcomes")
plt.ylabel("Age")
plt.savefig("Age_by_Outcomes.png")
plt.show()

# Type of Outcome (Dogs)
plt.figure(figsize=(12,8))
sns.countplot(x='outcome_type',data=intakes_outcomes_cleaned)
plt.title('Type of outcome Dogs in shelter')
plt.savefig("outcome_type.png")
plt.show()

# Euthanisia Types
euth=intakes_outcomes_cleaned[intakes_outcomes_cleaned["outcome_type"]=="Euthanasia"]
plt.figure(figsize=(12,8))
sns.countplot(x='outcome_subtype',data=euth)
plt.title('Why Dog was Euthanized')
plt.savefig("Euthanasia_data.png")
plt.show()

# Gmap Intake Locations

figure_layout = {
    'width': '1000px',
    'height': '1000px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto',
    'center':'30.2672, 97.7431',
    'zoom_level' :21
}

fig = gmaps.figure(layout=figure_layout)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations_coordinates, weights=locations_weight, 
                                 dissipating=False, max_intensity=1,
                                 point_radius=0.0025
                                )

fig.add_layer(heat_layer)

plt.savefig("Dogs found locations.png")
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-739a4a97be0e> in <module>
#      76 }
#      77
# ---> 78 fig = gmaps.figure(layout=figure_layout)
#      79 fig = gmaps.figure()
#      80
#
# NameError: name 'gmaps' is not defined
